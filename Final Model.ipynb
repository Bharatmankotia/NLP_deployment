# %%
import pandas as pd

# %%
data_raw=pd.read_csv("Downloads\\emails1(1).csv")

# %%
data=data_raw.iloc[:,3:] # slicing dataset

# %%
data[data['content'].duplicated(keep='first')] # checking for duplicate rows
# Out:
#                                                  content        Class
# 7      sorry i've taken so long...just been trying to...      Abusive
# 8      asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/23...      Abusive
# 9      asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/24...      Abusive
# 10     eat shit\n\n\n\n\nJohn J Lavorato@excelr\n11/1...      Abusive
# 11     Do you know my hr rep's name?\n\n\n\nJennifer ...      Abusive
# ...                                                  ...          ...
# 48071  Dear Market Participants,\n\nPlease note the c...  Non Abusive
# 48072  According to my fancy ciphering we made $310,0...  Non Abusive
# 48073  BUSINESS HIGHLIGHTS\n\nWeather Group\n\nLet=01...  Non Abusive
# 48074  Welcome to: DIAMONDS NEWSLETTER         Issue:...  Non Abusive
# 48075  ---------------------- Forwarded by Tamara Jae...  Non Abusive
#
# [23420 rows x 2 columns]

# %%
data_no_duplicates=data.drop_duplicates(['content'],keep='first') # dataset after removing duplicates

# %%
len(data_no_duplicates)
# Out:
# 24656

# %%
data_no_duplicates.head(50)
# Out:
#                                               content    Class
# 0   eat shit\n\n\n\n\nJohn J Lavorato@excelr\n11/1...  Abusive
# 1                                            fuck you  Abusive
# 2   Gentlemen:\nThe following champagne is availab...  Abusive
# 3   sorry i've taken so long...just been trying to...  Abusive
# 4   asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/23...  Abusive
# 5   asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/24...  Abusive
# 6   Do you know my hr rep's name?\n\n\n\nJennifer ...  Abusive
# 14  hey stupid-it is almost yr-end.  please do you...  Abusive
# 15  forgot to send this last week..\nhope you had ...  Abusive
# 16  \ngot this from late friday. have you ever hea...  Abusive
# 18  i hpe thingsa re ok for you.obviously a shit l...  Abusive
# 19  Agree.  Still not at supply/demand equilibrium...  Abusive
# 20  hey stupid:\ndo you know if jason ever signed ...  Abusive
# 21  are you going to blow me off for dinner again ...  Abusive
# 22  seems to me trade guys are getting royally fuc...  Abusive
# 23  sucks to be mediocre, huh?\n\n -----Original M...  Abusive
# 24  LOSER\n\n -----Original Message-----\nFrom: \t...  Abusive
# 25  me, me, me....you girls are all the same\n\n -...  Abusive
# 26  spinnaker, one of fred's customer's , unwound ...  Abusive
# 27  \n\n -----Original Message-----\nFrom: \t"Zeri...  Abusive
# 28                                      You're a jerk  Abusive
# 29  I spose so but we might have to take stupid as...  Abusive
# 37  ---------------------- Forwarded by Donald W H...  Abusive
# 40  \n\n-----Original Message-----\nFrom: orders@a...  Abusive
# 41  Jeff,\n Tim told me to put together a list of ...  Abusive
# 44  \n\n-----Original Message-----\nFrom:\tJudy Le...  Abusive
# 45  Steve,\n\nI have not laughed so hard in long t...  Abusive
# 46  \n\n-----Original Message-----\nFrom: Steve Ba...  Abusive
# 47  Thanks.\n\n -----Original Message-----\nFrom: ...  Abusive
# 48  that's good news about the location. i'll have...  Abusive
# 49  Your mom is so fat that God said "Let there be...  Abusive
# 50  I'm old now, but i can always find solace in t...  Abusive
# 51  she told me "you are not playing basketball on...  Abusive
# 52  I can't make it this week, but I will bring in...  Abusive
# 53  pussy\n\n\n   Hector Campos                01/...  Abusive
# 54  why not bitch?\n\n\n   Hector Campos          ...  Abusive
# 55  the bitch would like you to change the 1.5 MM ...  Abusive
# 56  SIPPING VODKA\nA new priest at his first mass ...  Abusive
# 57  ---------------------- Forwarded by Eric Bass/...  Abusive
# 58  http://www.oklahoman.com/cgi-bin/show_article?...  Abusive
# 59  What did you think of the debate?  I thought, ...  Abusive
# 60  do you want to go beat the crap out of some OU...  Abusive
# 61  Anyone up for half price pizza tonight, say ar...  Abusive
# 62  your running backs suck - what do you want for...  Abusive
# 63  Do you believe that your RBs suck now?  Do you...  Abusive
# 64  Your running backs suck.  I will give you Raym...  Abusive
# 65  so, there is nothing on my team that you are w...  Abusive
# 66  there have only been 2 (both by matt) is 1,14 ...  Abusive
# 67  kiss my ass now bitch!\n\n\n   \n\n\nFrom:  Br...  Abusive
# 68  You're right. We cheated by trying to screw ev...  Abusive

# %%
import re
import string

# %%
 def remove_url(text):
    url=re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r"", text)

def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r"", text)

# %%
data_no_duplicates['content']=data_no_duplicates['content'].apply(lambda x: remove_html(x)) # removing html and https content
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_no_duplicates.head(50)
# Out:
#                                               content    Class
# 0   eat shit\n\n\n\n\nJohn J Lavorato@excelr\n11/1...  Abusive
# 1                                            fuck you  Abusive
# 2   Gentlemen:\nThe following champagne is availab...  Abusive
# 3   sorry i've taken so long...just been trying to...  Abusive
# 4   asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/23...  Abusive
# 5   asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/24...  Abusive
# 6   Do you know my hr rep's name?\n\n\n\nJennifer ...  Abusive
# 14  hey stupid-it is almost yr-end.  please do you...  Abusive
# 15  forgot to send this last week..\nhope you had ...  Abusive
# 16  \ngot this from late friday. have you ever hea...  Abusive
# 18  i hpe thingsa re ok for you.obviously a shit l...  Abusive
# 19  Agree.  Still not at supply/demand equilibrium...  Abusive
# 20  hey stupid:\ndo you know if jason ever signed ...  Abusive
# 21  are you going to blow me off for dinner again ...  Abusive
# 22  seems to me trade guys are getting royally fuc...  Abusive
# 23  sucks to be mediocre, huh?\n\n -----Original M...  Abusive
# 24  LOSER\n\n -----Original Message-----\nFrom: \t...  Abusive
# 25  me, me, me....you girls are all the same\n\n -...  Abusive
# 26  spinnaker, one of fred's customer's , unwound ...  Abusive
# 27  \n\n -----Original Message-----\nFrom: \t"Zeri...  Abusive
# 28                                      You're a jerk  Abusive
# 29  I spose so but we might have to take stupid as...  Abusive
# 37  ---------------------- Forwarded by Donald W H...  Abusive
# 40  \n\n-----Original Message-----\nFrom: orders@a...  Abusive
# 41  Jeff,\n Tim told me to put together a list of ...  Abusive
# 44  \n\n-----Original Message-----\nFrom:\tJudy Le...  Abusive
# 45  Steve,\n\nI have not laughed so hard in long t...  Abusive
# 46  \n\n-----Original Message-----\nFrom: Steve Ba...  Abusive
# 47  Thanks.\n\n -----Original Message-----\nFrom: ...  Abusive
# 48  that's good news about the location. i'll have...  Abusive
# 49  Your mom is so fat that God said "Let there be...  Abusive
# 50  I'm old now, but i can always find solace in t...  Abusive
# 51  she told me "you are not playing basketball on...  Abusive
# 52  I can't make it this week, but I will bring in...  Abusive
# 53  pussy\n\n\n   Hector Campos                01/...  Abusive
# 54  why not bitch?\n\n\n   Hector Campos          ...  Abusive
# 55  the bitch would like you to change the 1.5 MM ...  Abusive
# 56  SIPPING VODKA\nA new priest at his first mass ...  Abusive
# 57  ---------------------- Forwarded by Eric Bass/...  Abusive
# 58  http://www.oklahoman.com/cgi-bin/show_article?...  Abusive
# 59  What did you think of the debate?  I thought, ...  Abusive
# 60  do you want to go beat the crap out of some OU...  Abusive
# 61  Anyone up for half price pizza tonight, say ar...  Abusive
# 62  your running backs suck - what do you want for...  Abusive
# 63  Do you believe that your RBs suck now?  Do you...  Abusive
# 64  Your running backs suck.  I will give you Raym...  Abusive
# 65  so, there is nothing on my team that you are w...  Abusive
# 66  there have only been 2 (both by matt) is 1,14 ...  Abusive
# 67  kiss my ass now bitch!\n\n\n   \n\n\nFrom:  Br...  Abusive
# 68  You're right. We cheated by trying to screw ev...  Abusive

# %%
data_no_duplicates['content'] = data_no_duplicates['content'].str.replace(r'[^\w]+', ' ') # provided space between the words and special characters. Removed punctuations as well
                                                                  # also removed \n from the data
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_no_duplicates.head(50)
# Out:
#                                               content    Class
# 0   eat shit John J Lavorato excelr 11 18 2000 01 ...  Abusive
# 1                                            fuck you  Abusive
# 2   Gentlemen The following champagne is available...  Abusive
# 3   sorry i ve taken so long just been trying to f...  Abusive
# 4   asshole John J Lavorato excelr 12 23 2000 10 5...  Abusive
# 5   asshole John J Lavorato excelr 12 24 2000 08 4...  Abusive
# 6   Do you know my hr rep s name Jennifer Burns 10...  Abusive
# 14  hey stupid it is almost yr end please do your ...  Abusive
# 15  forgot to send this last week hope you had a g...  Abusive
# 16   got this from late friday have you ever heard...  Abusive
# 18  i hpe thingsa re ok for you obviously a shit l...  Abusive
# 19  Agree Still not at supply demand equilibrium U...  Abusive
# 20  hey stupid do you know if jason ever signed an...  Abusive
# 21  are you going to blow me off for dinner again ...  Abusive
# 22  seems to me trade guys are getting royally fuc...  Abusive
# 23  sucks to be mediocre huh Original Message From...  Abusive
# 24  LOSER Original Message From Lavorato John Sent...  Abusive
# 25  me me me you girls are all the same Original M...  Abusive
# 26  spinnaker one of fred s customer s unwound a h...  Abusive
# 27   Original Message From Zerilli Frank excelr Se...  Abusive
# 28                                      You re a jerk  Abusive
# 29  I spose so but we might have to take stupid as...  Abusive
# 37   Forwarded by Donald W Herrick HOU ECT on 12 0...  Abusive
# 40   Original Message From orders amazon com mailt...  Abusive
# 41  Jeff Tim told me to put together a list of ino...  Abusive
# 44   Original Message From Judy Leslie Sent Thursd...  Abusive
# 45  Steve I have not laughed so hard in long time ...  Abusive
# 46   Original Message From Steve Bailey mailto sba...  Abusive
# 47  Thanks Original Message From Korkmas Deb Sent ...  Abusive
# 48  that s good news about the location i ll have ...  Abusive
# 49  Your mom is so fat that God said Let there be ...  Abusive
# 50  I m old now but i can always find solace in th...  Abusive
# 51  she told me you are not playing basketball on ...  Abusive
# 52  I can t make it this week but I will bring in ...  Abusive
# 53  pussy Hector Campos 01 24 2001 11 19 AM To Eri...  Abusive
# 54  why not bitch Hector Campos 01 24 2001 10 31 A...  Abusive
# 55  the bitch would like you to change the 1 5 MM ...  Abusive
# 56  SIPPING VODKA A new priest at his first mass w...  Abusive
# 57   Forwarded by Eric Bass HOU ECT on 10 19 2000 ...  Abusive
# 58  http www oklahoman com cgi bin show_article ID...  Abusive
# 59  What did you think of the debate I thought all...  Abusive
# 60  do you want to go beat the crap out of some OU...  Abusive
# 61  Anyone up for half price pizza tonight say aro...  Abusive
# 62  your running backs suck what do you want for h...  Abusive
# 63  Do you believe that your RBs suck now Do you w...  Abusive
# 64  Your running backs suck I will give you Raymon...  Abusive
# 65  so there is nothing on my team that you are wi...  Abusive
# 66  there have only been 2 both by matt is 1 14 fo...  Abusive
# 67  kiss my ass now bitch From Bryan Hull 07 19 20...  Abusive
# 68  You re right We cheated by trying to screw eve...  Abusive

# %%
data_no_duplicates['content'] = data_no_duplicates['content'].str.replace(r'[\d]+', ' ') # removed numbers from the dataset
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_no_duplicates.head()
# Out:
#                                              content    Class
# 0  eat shit John J Lavorato excelr           PM T...  Abusive
# 1                                           fuck you  Abusive
# 2  Gentlemen The following champagne is available...  Abusive
# 3  sorry i ve taken so long just been trying to f...  Abusive
# 4  asshole John J Lavorato excelr           AM To...  Abusive

# %%
data_new=data_no_duplicates[['Class','content']]

# %%
data_new.head()
# Out:
#      Class                                            content
# 0  Abusive  eat shit John J Lavorato excelr           PM T...
# 1  Abusive                                           fuck you
# 2  Abusive  Gentlemen The following champagne is available...
# 3  Abusive  sorry i ve taken so long just been trying to f...
# 4  Abusive  asshole John J Lavorato excelr           AM To...

# %%
data_new.isnull().sum() # check for missing values in each column
# Out:
# Class      0
# content    0
# dtype: int64

# %%
import nltk
stopwords=nltk.corpus.stopwords.words('english')

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
wn=nltk.WordNetLemmatizer()

# %%
dir(stopwords)

# %%
def process(text):
    text=[wn.lemmatize(word.lower()) for word in text.split() if word.lower() not in stopwords]
    return " ".join(text)

# %%
data_new['content']= data_new['content'].apply(lambda x: process(x))

# %%
data_new.head()
# Out:
#      Class                                            content
# 0  Abusive  eat shit john j lavorato excelr pm john arnold...
# 1  Abusive                                               fuck
# 2  Abusive  gentleman following champagne available approx...
# 3  Abusive  sorry taken long trying fend chick life sooooo...
# 4  Abusive  asshole john j lavorato excelr john arnold hou...

# %%
# without tfidf
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Convert a collection of text documents to a matrix of token counts
cv=CountVectorizer()

# %%
x=cv.fit_transform(data_new['content'])

# %%
cv.vocabulary_
# Out:
# {'eat': 25117,
#  'shit': 81412,
#  'john': 46051,
#  'lavorato': 50459,
#  'excelr': 29094,
#  'pm': 68654,
#  'arnold': 5072,
#  'hou': 39763,
#  'ect': 25428,
#  'cc': 13470,
#  'subject': 85728,
#  'football': 31950,
#  'bet': 8489,
#  'minn': 57067,
#  'buff': 11547,
#  'phil': 67749,
#  'indi': 42278,
#  'cinnci': 15069,
#  'det': 21563,
#  'clev': 15530,
#  'den': 21134,
#  'dall': 19720,
#  'jack': 44488,
#  'fuck': 32968,
#  'gentleman': 34306,
#  'following': 31882,
#  'champagne': 14155,
#  'available': 6216,
#  'approximate': 4592,
#  'retail': 75724,
#  'price': 70040,
#  'also': 3141,
#  'interest': 43104,
#  'trading': 90518,
#  'red': 74289,
#  'wine': 98978,
#  'derived': 21385,
#  'spec': 83647,
#  'website': 98015,
#  'winesearcer': 98988,
#  'com': 16261,
#  'stored': 85266,
#  'temperature': 88113,
#  'controlled': 17443,
#  'private': 70180,
#  'storage': 85259,
#  'facility': 29793,
#  'quan': 72387,
#  'vintage': 95900,
#  'perrier': 67358,
#  'jouet': 46252,
#  'brut': 11285,
#  'fleur': 31504,
#  'de': 20403,
#  'piper': 68123,
#  'heidsek': 38177,
#  'reserve': 75456,
#  'dom': 23379,
#  'perignon': 67273,
#  'veuve': 95543,
#  'cliquot': 15623,
#  'ponsardin': 69019,
#  'la': 49856,
#  'grande': 35873,
#  'dame': 19754,
#  'taittenger': 87187,
#  'millesine': 56924,
#  'jacquart': 44524,
#  'roederer': 77164,
#  'cristal': 18531,
#  'sorry': 83410,
#  'taken': 87206,
#  'long': 52548,
#  'trying': 91274,
#  'fend': 30560,
#  'chick': 14583,
#  'life': 51534,
#  'sooooo': 83350,
#  'hard': 37461,
#  'sometimes': 83275,
#  'monkey': 57988,
#  'brian': 10900,
#  'rourke': 77521,
#  'communication': 16496,
#  'yeah': 101736,
#  'hey': 38532,
#  'little': 51936,
#  'bastard': 7423,
#  'picture': 67947,
#  'company': 16529,
#  'think': 88888,
#  'help': 38262,
#  'score': 79841,
#  'woman': 99461,
#  'say': 79312,
#  'balance': 6948,
#  'sheet': 81218,
#  'asshole': 5511,
#  'cant': 12668,
#  'seem': 80326,
#  'make': 54126,
#  'gambling': 33638,
#  'problem': 70246,
#  'go': 35343,
#  'away': 6401,
#  'bill': 9020,
#  'denver': 21215,
#  'ram': 73158,
#  'wash': 97461,
#  'raider': 73080,
#  'balt': 7036,
#  'bear': 7851,
#  'lion': 51787,
#  'eagle': 24959,
#  'bengal': 8300,
#  'pat': 66482,
#  'viking': 95846,
#  'know': 48824,
#  'hr': 39965,
#  'rep': 75171,
#  'name': 59614,
#  'jennifer': 45209,
#  'burn': 11768,
#  'head': 37979,
#  'stupid': 85648,
#  'almost': 3081,
#  'yr': 102411,
#  'end': 27073,
#  'please': 68509,
#  'mid': 56711,
#  'year': 101738,
#  'review': 75908,
#  'never': 60572,
#  'going': 35420,
#  'squeeze': 84244,
#  'lime': 51658,
#  'believe': 8182,
#  'reduced': 74399,
#  'pathetic': 66519,
#  'begging': 8070,
#  'empty': 26941,
#  'threat': 89036,
#  'killing': 48261,
#  'forgot': 32085,
#  'send': 80522,
#  'last': 50320,
#  'week': 98074,
#  'hope': 39579,
#  'good': 35494,
#  'wknd': 99232,
#  'ca': 12200,
#  'original': 64776,
#  'message': 56262,
#  'abramo': 655,
#  'caroline': 12983,
#  'sent': 80573,
#  'wed': 98039,
#  'gomez': 35466,
#  'julie': 46714,
#  'lagrasta': 50005,
#  'fred': 32499,
#  'fw': 33261,
#  'shut': 81675,
#  'generate': 34251,
#  'cash': 13112,
#  'flow': 31619,
#  'morning': 58203,
#  'produced': 70324,
#  'marking': 54698,
#  'desk': 21491,
#  'houston': 39812,
#  'deal': 20425,
#  'small': 82640,
#  'midsize': 56763,
#  'independent': 42256,
#  'predominately': 69738,
#  'unhedged': 93379,
#  'idea': 41083,
#  'originated': 64782,
#  'statement': 84743,
#  'mark': 54627,
#  'pappa': 66194,
#  'eog': 27599,
#  'could': 17927,
#  'possibly': 69244,
#  'production': 70338,
#  'certain': 13900,
#  'level': 51180,
#  'response': 75590,
#  'intent': 43040,
#  'suggestion': 85985,
#  'view': 95796,
#  'in': 42015,
#  'near': 60188,
#  'term': 88247,
#  'producer': 70325,
#  'looking': 52599,
#  'would': 99674,
#  'occur': 63088,
#  'several': 80771,
#  'month': 58064,
#  'currently': 19166,
#  'contangos': 17327,
#  'time': 89333,
#  'high': 38750,
#  'nov': 61904,
#  'cent': 13821,
#  'dec': 20523,
#  'cy': 19435,
#  'one': 64057,
#  'shutting': 81686,
#  'soon': 83344,
#  'hear': 38043,
#  'anyone': 4218,
#  'let': 51132,
#  'perspective': 67413,
#  'still': 85074,
#  'advocate': 1628,
#  'short': 81493,
#  'st': 84468,
#  'call': 12418,
#  'question': 72480,
#  'set': 80722,
#  'discussion': 22505,
#  'fundy': 33097,
#  'specialist': 83665,
#  'jim': 45595,
#  'schweiger': 79763,
#  'texas': 88435,
#  'operator': 64386,
#  'coming': 16338,
#  'rockies': 77111,
#  'canadian': 12569,
#  'thought': 89001,
#  'got': 35607,
#  'late': 50339,
#  'friday': 32651,
#  'ever': 28844,
#  'heard': 38044,
#  'jeff': 45127,
#  'lawson': 50486,
#  'mailto': 54058,
#  'jeffreyskilling': 45155,
#  'yahoo': 101522,
#  'wednesday': 98060,
#  'november': 61924,
#  'zipper': 103356,
#  'andy': 3781,
#  'piece': 67962,
#  'wait': 97216,
#  'see': 80305,
#  'ship': 81374,
#  'like': 51604,
#  'vermin': 95467,
#  'smug': 82830,
#  'paranoid': 66246,
#  'unhappy': 93374,
#  'mother': 58287,
#  'fucker': 32971,
#  '__________________________________________________': 45,
#  'geocities': 34323,
#  'quick': 72509,
#  'easy': 25112,
#  'web': 97970,
#  'site': 82095,
#  'hosting': 39693,
#  'http': 40159,
#  'info': 42505,
#  'hpe': 39888,
#  'thingsa': 88887,
#  'ok': 63693,
#  'obviously': 63045,
#  'load': 52327,
#  'rumour': 78188,
#  'circulating': 15107,
#  'youll': 102280,
#  'personally': 67402,
#  'fun': 33060,
#  'im': 41699,
#  'cool': 17541,
#  'agree': 2104,
#  'supply': 86277,
#  'demand': 21060,
#  'equilibrium': 27891,
#  'unfortunately': 93354,
#  'market': 54648,
#  'lack': 49919,
#  'catalyst': 13228,
#  'sharp': 81124,
#  'move': 58385,
#  'bid': 8891,
#  'continu': 17379,
#  'slow': 82572,
#  'erosion': 28127,
#  'slowly': 82582,
#  'running': 78208,
#  'place': 68356,
#  'put': 71209,
#  'ga': 33460,
#  'discretionary': 22490,
#  'guy': 36754,
#  'belly': 8224,
#  'full': 33037,
#  'future': 33201,
#  'keep': 47668,
#  'widening': 98747,
#  'spread': 84068,
#  'even': 28825,
#  'though': 88998,
#  'widens': 98748,
#  'every': 28866,
#  'day': 20117,
#  'way': 97586,
#  'get': 34463,
#  'nowhere': 61953,
#  'ut': 94377,
#  'gas': 33811,
#  'buy': 11923,
#  'cantango': 12672,
#  'winter': 99037,
#  'money': 57956,
#  'strongest': 85539,
#  'product': 70331,
#  'nymex': 62702,
#  'ev': 28768,
#  'erything': 28211,
#  'else': 26584,
#  'bloodbath': 9642,
#  'socal': 83050,
#  'basis': 7399,
#  'gone': 35473,
#  'ast': 5581,
#  'ridiculous': 76326,
#  'import': 41928,
#  'blow': 9672,
#  'new': 60585,
#  'lng': 52284,
#  'novy': 61945,
#  'rig': 76356,
#  'count': 17949,
#  'ope': 64336,
#  'straight': 85340,
#  'line': 51722,
#  'behaving': 8098,
#  'inelastic': 42394,
#  'craziest': 18348,
#  'board': 9871,
#  'fundamentally': 33083,
#  'priced': 70043,
#  'reason': 73908,
#  'industry': 42373,
#  'us': 94203,
#  'primaril': 70081,
#  'link': 51760,
#  'front': 32741,
#  'back': 6737,
#  'dr': 23851,
#  'ifting': 41302,
#  'lower': 52791,
#  'find': 31089,
#  'customer': 19232,
#  'support': 86282,
#  'cal': 12335,
#  'ish': 43882,
#  'thus': 89139,
#  'come': 16298,
#  'plus': 68632,
#  'fundamental': 33080,
#  'side': 81738,
#  'lafontaine': 49983,
#  'steve': 85000,
#  'ilto': 41686,
#  'imceanotes': 41748,
#  'csteve': 18854,
#  'elafontaine': 26288,
#  'banko': 7131,
#  'famerica': 29939,
#  'ecom': 25366,
#  'june': 46749,
#  'jarnold': 44781,
#  'mkt': 57448,
#  'suck': 85903,
#  'much': 58867,
#  'change': 14182,
#  'dont': 23490,
#  'bull': 11621,
#  'hot': 39697,
#  'summer': 86085,
#  'pt': 70890,
#  'delay': 20920,
#  'bearishness': 7862,
#  'tcf': 87679,
#  'bullish': 11644,
#  'oct': 63156,
#  'rest': 75623,
#  'either': 26148,
#  'hell': 38237,
#  'bo': 9865,
#  'buying': 11932,
#  'lookin': 52598,
#  'aug': 6011,
#  'remember': 75007,
#  'ct': 18878,
#  'maybe': 55159,
#  'redicuous': 74339,
#  'world': 99594,
#  'give': 34919,
#  'strip': 85503,
#  'reasonalbe': 73915,
#  'jan': 44682,
#  'feb': 30419,
#  'mar': 54464,
#  'seems': 80332,
#  'treating': 90848,
#  'well': 98187,
#  'pluggin': 68606,
#  'along': 3099,
#  'far': 30014,
#  'pretty': 69983,
#  'unwavering': 93815,
#  'bearish': 7861,
#  'conviction': 17500,
#  'stil': 85072,
#  'buck': 11481,
#  'always': 3240,
#  'wip': 99047,
#  'take': 87199,
#  'cust': 19218,
#  'stuff': 85619,
#  'finally': 31056,
#  'cooled': 17543,
#  'hedged': 38126,
#  'industrial': 42365,
#  'sector': 80262,
#  'suffering': 85950,
#  'bad': 6814,
#  'margin': 54546,
#  'chemical': 14473,
#  'biz': 9281,
#  'due': 24367,
#  'ammonia': 3499,
#  'metal': 56296,
#  'resid': 75478,
#  'bcf': 7677,
#  'regard': 74590,
#  'number': 62411,
#  'jason': 44799,
#  'signed': 81830,
#  'evergreen': 28851,
#  'print': 70123,
#  'dinner': 22282,
#  'tonight': 90047,
#  'trade': 90486,
#  'getting': 34490,
#  'royally': 77588,
#  'fucked': 32970,
#  'crude': 18696,
#  'mediocre': 55865,
#  'huh': 40242,
#  'monday': 57935,
#  'october': 63166,
#  'sf': 80822,
#  'nyj': 62693,
#  'loser': 52682,
#  'stl': 85127,
#  'girl': 34886,
#  'slone': 82552,
#  'jeanie': 45090,
#  'tuesday': 91482,
#  'spinnaker': 83847,
#  'unwound': 93833,
#  'hedge': 38123,
#  'today': 89864,
#  'want': 97347,
#  'exposure': 29505,
#  'zerilli': 103144,
#  'frank': 32435,
#  'bnp': 9850,
#  'request': 75353,
#  'efs': 25858,
#  'transaction': 90611,
#  'paribas': 66284,
#  'may': 55151,
#  'swap': 86591,
#  'jun': 46742,
#  'jul': 46701,
#  'sep': 80591,
#  'sell': 80448,
#  'apr': 4620,
#  'cantdo': 12673,
#  'part': 66346,
#  'string': 85495,
#  'attached': 5819,
#  'opposite': 64473,
#  'thanks': 88634,
#  'jerk': 45260,
#  'spose': 84014,
#  'might': 56793,
#  'found': 32234,
#  'forwarded': 32202,
#  'donald': 23424,
#  'herrick': 38455,
#  'north': 61778,
#  'america': 3393,
#  'corp': 17746,
#  'kyle': 49769,
#  'roblee': 77060,
#  'paul': 66594,
#  'pizzolato': 68257,
#  'christopher': 14848,
#  'helfrich': 38229,
#  'eric': 28023,
#  'scott': 79869,
#  'brandon': 10684,
#  'neff': 60277,
#  'ee': 25656,
#  'keith': 47692,
#  'crane': 18307,
#  'azurix': 6659,
#  'santa': 79065,
#  'answered': 4075,
#  'mail': 54007,
#  'na': 59497,
#  'jeffery': 45139,
#  'mcvey': 55662,
#  'better': 8535,
#  'mcdaniel': 55403,
#  'dave': 20034,
#  'aslanian': 5415,
#  'galbraith': 33570,
#  'jerry': 45278,
#  'garber': 33725,
#  'randy': 73255,
#  'boutte': 10426,
#  'robert': 77023,
#  'egger': 25905,
#  'stu': 85589,
#  'smith': 82750,
#  'kern': 47849,
#  'dear': 20458,
#  'wud': 100091,
#  'kool': 48971,
#  'toy': 90334,
#  'space': 83545,
#  'ranjur': 73286,
#  'fer': 30583,
#  'xmas': 100868,
#  'iv': 44228,
#  'ben': 8251,
#  'gud': 36547,
#  'boy': 10479,
#  'yeer': 101757,
#  'yer': 101803,
#  'frend': 32594,
#  'chuck': 14909,
#  'nice': 61018,
#  'spelling': 83763,
#  'career': 12868,
#  'lawn': 50476,
#  'care': 12863,
#  'elementary': 26403,
#  'reading': 73802,
#  'book': 10167,
#  'learn': 50775,
#  'read': 73794,
#  'write': 99865,
#  'giving': 34929,
#  'older': 63773,
#  'brother': 11169,
#  'ranger': 73280,
#  'least': 50793,
#  'spell': 83758,
#  'thing': 88885,
#  'ask': 5402,
#  'peace': 66887,
#  'joy': 46273,
#  'everybody': 28868,
#  'love': 52755,
#  'sarah': 79120,
#  'parent': 66271,
#  'smoked': 82780,
#  'pot': 69298,
#  'christmas': 14840,
#  'mommy': 57912,
#  'daddy': 19622,
#  'together': 89895,
#  'teddy': 87927,
#  'look': 52589,
#  'dad': 19618,
#  'banging': 7103,
#  'babysitter': 6723,
#  'screen': 79937,
#  'door': 23515,
#  'hurricane': 40392,
#  'gonna': 35478,
#  'frigid': 32690,
#  'mom': 57902,
#  'ride': 76312,
#  'butt': 11891,
#  'constantly': 17223,
#  'dream': 23935,
#  'lego': 50951,
#  'instead': 42897,
#  'bike': 8988,
#  'playstation': 68489,
#  'train': 90556,
#  'joes': 46020,
#  'dog': 23317,
#  'drum': 24118,
#  'kit': 48434,
#  'pony': 69026,
#  'tuba': 91452,
#  'francis': 32422,
#  'kid': 48205,
#  'nowadays': 61948,
#  'gay': 33934,
#  'left': 50897,
#  'milk': 56904,
#  'cooky': 17540,
#  'tree': 90861,
#  'carrot': 13041,
#  'reindeer': 74753,
#  'outside': 65320,
#  'susan': 86428,
#  'run': 78194,
#  'deer': 20717,
#  'fart': 30073,
#  'face': 29761,
#  'riding': 76330,
#  'sleigh': 82468,
#  'favor': 30183,
#  'leave': 50802,
#  'bottle': 10362,
#  'scotch': 79860,
#  'busy': 11881,
#  'making': 54143,
#  'friend': 32666,
#  'thomas': 88954,
#  'made': 53845,
#  'china': 14632,
#  'condo': 16864,
#  'vega': 95281,
#  'spend': 83771,
#  'low': 52782,
#  'budget': 11524,
#  'porno': 69130,
#  'film': 31017,
#  'unwind': 93823,
#  'drinking': 24018,
#  'silly': 81890,
#  'squeezing': 84246,
#  'ass': 5465,
#  'cocktail': 15986,
#  'waitress': 97222,
#  'losing': 52686,
#  'crap': 18313,
#  'table': 87071,
#  'wanted': 97348,
#  'sleeping': 82461,
#  'really': 73860,
#  'awake': 6379,
#  'song': 83308,
#  'jessica': 45305,
#  'gullible': 36653,
#  'luck': 53176,
#  'whatever': 98476,
#  'skipping': 82292,
#  'house': 39790,
#  'puppy': 71116,
#  'timmy': 89370,
#  'whiney': 98561,
#  'work': 99550,
#  'folk': 31867,
#  'sweater': 86639,
#  'dearest': 20460,
#  'chimney': 14629,
#  'home': 39424,
#  'marky': 54713,
#  'first': 31215,
#  'stop': 85242,
#  'calling': 12440,
#  'as': 5294,
#  'whipped': 98569,
#  'school': 79682,
#  'second': 80242,
#  'live': 51956,
#  'rent': 75133,
#  'apartment': 4334,
#  'complex': 16631,
#  'third': 88908,
#  'inside': 42813,
#  'pad': 65881,
#  'burglar': 11740,
#  'bedroom': 8005,
#  'window': 98965,
#  'sweet': 86662,
#  'order': 64671,
#  'amazon': 3315,
#  'arora': 5093,
#  'harry': 37594,
#  'approval': 4578,
#  'required': 75364,
#  'hello': 38249,
#  'experiencing': 29419,
#  'item': 44080,
#  'masami': 54882,
#  'saionji': 78786,
#  'golden': 35434,
#  'key': 47931,
#  'happiness': 37422,
#  'word': 99540,
#  'guidance': 36594,
#  'wisdom': 99075,
#  'delayed': 20922,
#  'approve': 4580,
#  'cancel': 12581,
#  'www': 100224,
#  'availability': 6214,
#  'bwvkratkzgnwh': 12035,
#  'received': 74045,
#  'cancellation': 12585,
#  'try': 91265,
#  'obtain': 63031,
#  'date': 19991,
#  'otherwise': 65078,
#  'automatically': 6153,
#  'clicking': 15557,
#  'copy': 17635,
#  'paste': 66467,
#  'browser': 11206,
#  'address': 1283,
#  'retype': 75827,
#  'apologize': 4414,
#  'inconvenience': 42173,
#  'caused': 13338,
#  'shopping': 81485,
#  'sincerely': 81983,
#  'service': 80694,
#  'department': 21246,
#  'earth': 25061,
#  'biggest': 8949,
#  'selection': 80429,
#  'tim': 89320,
#  'told': 89939,
#  'list': 51873,
#  'inormation': 42757,
#  'iso': 43944,
#  'general': 34239,
#  'rule': 78161,
#  'information': 42538,
#  'released': 74880,
#  'highlight': 38764,
#  'etc': 28510,
#  'schedule': 79565,
#  'transmission': 90696,
#  'da': 19593,
#  'ha': 36998,
#  'submitted': 85753,
#  'path': 66516,
#  'nw': 62551,
#  'az': 6599,
#  'lc': 50587,
#  'actual': 1144,
#  'real': 73823,
#  'many': 54432,
#  'mw': 59265,
#  'cut': 19255,
#  'adjustment': 1383,
#  'stack': 84499,
#  'intrazonal': 43297,
#  'cong': 17009,
#  'intra': 43280,
#  'zonal': 103585,
#  'beep': 8036,
#  'generation': 34255,
#  'sc': 79412,
#  'plant': 68407,
#  'judy': 46663,
#  'leslie': 51112,
#  'thursday': 89136,
#  'january': 44739,
#  'bailey': 6897,
#  'jdv': 45070,
#  'need': 60246,
#  'garbage': 33721,
#  'collector': 16151,
#  'stealing': 84830,
#  'suddenly': 85922,
#  'stand': 84607,
#  'lying': 53555,
#  'coffee': 16017,
#  'roll': 77229,
#  'behind': 8109,
#  'fridge': 32653,
#  'sofa': 83108,
#  'shake': 80985,
#  'rainwater': 73115,
#  'fur': 33141,
#  'enter': 27419,
#  'cat': 13212,
#  'food': 31923,
#  'throw': 89085,
#  'necessary': 60224,
#  'remaining': 74968,
#  'clean': 15454,
#  'carpet': 12999,
#  'sick': 81726,
#  'bathroom': 7457,
#  'wastebasket': 97485,
#  'cookie': 17529,
#  'jar': 44761,
#  'chew': 14545,
#  'human': 40280,
#  'toothbrush': 90100,
#  'tell': 88069,
#  'crayon': 18343,
#  'pen': 67068,
#  'especially': 28336,
#  'people': 67157,
#  'hemorrhaging': 38299,
#  'car': 12803,
#  'insist': 42831,
#  'rolled': 77233,
#  'raining': 73109,
#  'since': 81979,
#  'doorbell': 23516,
#  'bark': 7262,
#  'tv': 91679,
#  'steal': 84829,
#  'underwear': 93220,
#  'dance': 19793,
#  'backyard': 6809,
#  'towel': 90310,
#  'belong': 8230,
#  'refrigerator': 74553,
#  'bite': 9245,
#  'officer': 63365,
#  'hand': 37271,
#  'reach': 73772,
#  'driver': 24035,
#  'license': 51487,
#  'registration': 74656,
#  'play': 68459,
#  'tug': 91489,
#  'war': 97367,
#  'toilet': 89914,
#  'mint': 57090,
#  'flavored': 31452,
#  'dental': 21206,
#  'floss': 31607,
#  'worm': 99619,
#  'hanging': 37346,
#  'obligated': 62966,
#  'around': 5099,
#  'dirt': 22349,
#  'immediately': 41798,
#  'bath': 7453,
#  'bowl': 10452,
#  'ending': 27099,
#  'water': 97513,
#  'sticking': 85046,
#  'nose': 61816,
#  'someone': 83262,
#  'crotch': 18643,
#  'acceptable': 781,
#  'saying': 79319,
#  'squeaky': 84239,
#  'noise': 61592,
#  'probably': 70231,
#  'turd': 91586,
#  'candy': 12620,
#  'laughed': 50394,
#  'refreshing': 74548,
#  'definately': 20792,
#  'reminded': 75020,
#  'suggie': 85990,
#  'sbailey': 79335,
#  'crusescott': 18733,
#  'korkmas': 49005,
#  'deb': 20471,
#  'chiricahua': 14659,
#  'note': 61843,
#  'per': 67192,
#  'news': 60651,
#  'location': 52384,
#  'visit': 95988,
#  'artillery': 5236,
#  'gotten': 35621,
#  'yet': 101825,
#  'later': 50344,
#  'brett': 10872,
#  'lawler': 50470,
#  'bass': 7412,
#  'winning': 99023,
#  'cultural': 19062,
#  'awesome': 6410,
#  'attationed': 5851,
#  'hawaii': 37781,
#  'welcome': 98177,
#  'break': 10781,
#  'shithole': 81414,
#  'ft': 32880,
#  'sill': 81885,
#  'pre': 69649,
#  'bitch': 9238,
#  'class': 15389,
#  'start': 84690,
#  'nothin': 61854,
#  'goin': 35418,
#  '______________________________________________________': 48,
#  'free': 32515,
#  'email': 26640,
#  'hotmail': 39735,
#  'fat': 30125,
#  'god': 35367,
#  'said': 78764,
#  'light': 51570,
#  'right': 76364,
#  'moved': 58386,
#  'old': 63766,
#  'solace': 83154,
#  'fact': 29802,
#  'woody': 99509,
#  'richmond': 76269,
#  'used': 94246,
#  'velvet': 95339,
#  'elvis': 26616,
#  'happy': 37424,
#  'birthday': 9202,
#  'feel': 30470,
#  'technical': 87890,
#  'engineer': 27237,
#  'compa': 16516,
#  'playing': 68478,
#  'basketball': 7403,
#  'interpret': 43192,
#  'however': 39850,
#  'game': 33642,
#  'ball': 6983,
#  'bring': 10991,
#  'jersey': 45287,
#  'pussy': 71205,
#  'hector': 38119,
#  'campos': 12556,
#  'hoskins': 39671,
#  'paintball': 65961,
#  'saturday': 79227,
#  'mm': 57525,
#  'offer': 63347,
#  'sipping': 82055,
#  'vodka': 96337,
#  'priest': 70071,
#  'mass': 54913,
#  'nervous': 60427,
#  'hardly': 37484,
#  'speak': 83634,
#  'asked': 5405,
#  'monsignor': 58022,
#  'done': 23447,
#  'replied': 75236,
#  'worried': 99629,
#  'pulpit': 71047,
#  'glass': 35050,
#  'next': 60772,
#  'sip': 82044,
#  'sunday': 86127,
#  'took': 90077,
#  'advice': 1607,
#  'beginning': 8079,
#  'sermon': 80674,
#  'drink': 24014,
#  'proceeded': 70272,
#  'talk': 87244,
#  'storm': 85278,
#  'upon': 93980,
#  'return': 75820,
#  'office': 63362,
#  'gulp': 36658,
#  'commandment': 16355,
#  'disciple': 22424,
#  'jesus': 45311,
#  'consecrated': 17133,
#  'constipated': 17228,
#  'jacob': 44512,
#  'wagered': 97166,
#  'donkey': 23457,
#  'refer': 74461,
#  'christ': 14816,
#  'father': 30136,
#  'son': 83290,
#  'holy': 39413,
#  'ghost': 34668,
#  'referred': 74478,
#  'junior': 46760,
#  'spook': 83960,
#  'david': 20047,
#  'slew': 82478,
#  'goliath': 35458,
#  'kick': 48192,
#  'hit': 38955,
#  ...}

# %%
# Checking for imbalance in the data
import matplotlib.pyplot as plt
count_classes=pd.value_counts(data_new['Class'],sort=True)
count_classes.plot(kind='bar',rot=0)

# %%
abusive=data_new[data_new['Class']=='Abusive']
non_abusive=data_new[data_new['Class']=='Non Abusive']

# %%
print(abusive.shape,non_abusive.shape) # our dataset is imbalanced
# Out:
# (1642, 2) (23014, 2)

# %%
# Building multinomial naive bayes model
from sklearn.naive_bayes import MultinomialNB as MB

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,data_new['Class'],test_size=0.20,random_state=0)

# %%
from imblearn.over_sampling import SMOTE # importing smote for oversampling to counter imbalanced dataset

# %%
smote=SMOTE()

# %%
x_train_smote,y_train_smote=smote.fit_sample(x_train,y_train)

# %%
from collections import Counter

# %%
clf=MB()
classifier=clf.fit(x_train_smote,y_train_smote)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
pred=classifier.predict(x_train_smote)
print(classification_report(y_train_smote,pred))
# Out:
#               precision    recall  f1-score   support
#
#      Abusive       0.98      0.87      0.92     18404
#  Non Abusive       0.88      0.98      0.93     18404
#
#     accuracy                           0.93     36808
#    macro avg       0.93      0.93      0.93     36808
# weighted avg       0.93      0.93      0.93     36808

# %%
print(confusion_matrix(y_train_smote,pred))
# Out:
# [[16011  2393]
#  [  308 18096]]

# %%
print('accuracy:', accuracy_score(y_train_smote,pred)) # accuracy of 0.93
# Out:
# accuracy: 0.9266192132145186

# %%
pred_test=classifier.predict(x_test)

# %%
print(confusion_matrix(y_test,pred_test))
# Out:
# [[ 193  129]
#  [  88 4522]]

# %%
print('accuracy:', accuracy_score(y_test,pred_test)) # 0.95
# Out:
# accuracy: 0.9560016220600163

# %%
import pickle

# %%
joblib.dump(cv,open('transform.pkl', 'wb'))

# %%
filename='nlp_model.pkl'
pickle.dump(clf, open(filename, 'wb'))

# %%
# Using tfidf 
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
cv_tfidf=TfidfVectorizer(analyzer=process)

# %%
x_tfidf=cv_tfidf.fit_transform(data_new['content_without_no'])

# %%
x_tfidf_train,x_tfidf_test,y_tfidf_train,y_tfidf_test=train_test_split(x_tfidf,data_new['Class'],test_size=0.20,random_state=0)

# %%
x_tfidf_train_smote,y_tfidf_train_smote=smote.fit_sample(x_tfidf_train,y_tfidf_train)

# %%
print("Before smote:", Counter(y_train))
print("After smote:", Counter(y_tfidf_train_smote)) # Checking whether over sampling worked properly

# %%
classifier_tfidf=MB().fit(x_tfidf_train_smote,y_tfidf_train_smote)

# %%
pred_tfidf=classifier_tfidf.predict(x_tfidf_train_smote)
print(classification_report(y_tfidf_train_smote,pred_tfidf))

# %%
print(confusion_matrix(y_tfidf_train_smote,pred_tfidf))

# %%
print('accuracy:', accuracy_score(y_tfidf_train_smote,pred_tfidf)) # accuracy of 0.96

# %%
pred_test_tfidf=classifier_tfidf.predict(x_tfidf_test)

# %%
print(confusion_matrix(y_tfidf_test,pred_test_tfidf))

# %%
print('accuracy:', accuracy_score(y_tfidf_test,pred_test_tfidf)) # accuracy of 0.94
